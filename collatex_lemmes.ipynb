# %% [markdown]
# # La typologie des variantes

# %%
import collatex
import json
import time

# %%
# On va importer les données lemmatisées
with open("Catullus/annotated/TEXT-O1.txt", "r") as input_text:
    text_1 = [line.replace("\n", "") for line in input_text.readlines()][1:]

# et 2
with open("Catullus/annotated/TEXT-G2.txt", "r") as input_text:
    text_2 = [line.replace("\n", "") for line in input_text.readlines()][1:]


# et 3
with open("Catullus/annotated/TEXT-Bodmer47-1.txt", "r") as input_text:
    text_3 = [line.replace("\n", "") for line in input_text.readlines()][1:]

# %%
def import_annotated_data(input_text:str):
    output_list = []
    for line in input_text:
        splits = line.split("\t")[:-2]
        output_list.append(splits)
    return output_list

def create_json_input_for_collatex(dict_of_text):
    output_dict = {"witnesses": []}
    for sigla, text in dict_of_text.items():
        witness_dict = {"id": sigla}
        tokens = []
        for token in text:
            form, lemma, pos, morph = token
            tokens.append({"t": form, "n":lemma, "lemma": lemma, "pos": pos, "morph": morph})
        witness_dict["tokens"] = tokens
        output_dict["witnesses"].append(witness_dict)
    return output_dict

# %%
text_1_as_list = import_annotated_data(text_1)
text_2_as_list = import_annotated_data(text_2)
text_3_as_list = import_annotated_data(text_3)
dict_of_text = {"O1": text_1_as_list, "G2": text_2_as_list, "Bodmer47": text_3_as_list}

json_input = create_json_input_for_collatex(dict_of_text)

# %%
resultat_json = collatex.collate(json_input, output='json', segmentation=False, near_match=True)
alignment_results_as_json = json.loads(resultat_json)

# %%
# Si on compare avec l'alignement sur les formes, on a des erreurs en moins.
result_table = collatex.collate(json_input, layout='vertical', segmentation=False)
print(result_table)
# Out:
# +------------+------------+--------------+
# |     O1     |     G2     |   Bodmer47   |
# +------------+------------+--------------+
# |     -      |   fletus   |      -       |
# +------------+------------+--------------+
# |     -      |  passeris  |   Passeris   |
# +------------+------------+--------------+
# |     -      |   lesbie   |  appelatio   |
# +------------+------------+--------------+
# |   Passer   |   Passer   |    Passer    |
# +------------+------------+--------------+
# |  delicie   |  delicie   |   delitiae   |
# +------------+------------+--------------+
# |    mee     |    mee     |     meae     |
# +------------+------------+--------------+
# |   puelle   |   puelle   |   puellae    |
# +------------+------------+--------------+
# |    Qui     |    Qui     |     Qui      |
# +------------+------------+--------------+
# |    cum     |    cum     |     cum      |
# +------------+------------+--------------+
# |   ludere   |   ludere   |    ludere    |
# +------------+------------+--------------+
# |    quem    |    quem    |     quem     |
# +------------+------------+--------------+
# |     in     |     in     |      in      |
# +------------+------------+--------------+
# |    sinu    |    sinu    |     sinu     |
# +------------+------------+--------------+
# |   tenere   |   tenere   |    tenere    |
# +------------+------------+--------------+
# |    Qui     |    Qui     |     Quoi     |
# +------------+------------+--------------+
# |   primum   |   primum   |    primum    |
# +------------+------------+--------------+
# |  digitum   |  digitum   |   digitum    |
# +------------+------------+--------------+
# |    dare    |    dare    |     dare     |
# +------------+------------+--------------+
# |     at     |     at     |  appententi  |
# +------------+------------+--------------+
# |  petenti   |  patenti   |    Atque     |
# +------------+------------+--------------+
# |     Ea     |     Et     |      -       |
# +------------+------------+--------------+
# |   acris    |   acris    |    acris     |
# +------------+------------+--------------+
# |   solet    |   solet    |    solet     |
# +------------+------------+--------------+
# |  incitare  |  incitare  |   incitare   |
# +------------+------------+--------------+
# |   morsus   |   morsus   |    morsus    |
# +------------+------------+--------------+
# |    Cum     |    Cum     |     Cum      |
# +------------+------------+--------------+
# | desiderio  | desiderio  |  desyderio   |
# +------------+------------+--------------+
# |    meo     |    meo     |     meo      |
# +------------+------------+--------------+
# |  nitenti   |  nitenti   |   nitenti    |
# +------------+------------+--------------+
# |   Karum    |   Carum    |    Charum    |
# +------------+------------+--------------+
# |   nescio   |   nescio   |    nescio    |
# +------------+------------+--------------+
# |    quid    |    quid    |     quid     |
# +------------+------------+--------------+
# |   libet    |   libet    |    libet     |
# +------------+------------+--------------+
# |   iocari   |   iocari   |    iocari    |
# +------------+------------+--------------+
# |     Et     |     Et     | Insolatiolum |
# +------------+------------+--------------+
# | solaciolum | solaciolum |      -       |
# +------------+------------+--------------+
# |    sui     |    sui     |     sui      |
# +------------+------------+--------------+
# |  doloris   |  doloris   |   doloris    |
# +------------+------------+--------------+
# |   Credo    |   Credo    |    Credo     |
# +------------+------------+--------------+
# |     ut     |     ut     |      ut      |
# +------------+------------+--------------+
# |    cum     |    cum     |     quum     |
# +------------+------------+--------------+
# |   gravis   |   gravis   |    gravis    |
# +------------+------------+--------------+
# | acquiescet | adquiescet |  acquiescat  |
# +------------+------------+--------------+
# |   ardor    |   ardor    |    ardor     |
# +------------+------------+--------------+
# |   Tecum    |   Tecum    |    Tecum     |
# +------------+------------+--------------+
# |  {Tecum}   |  {Tecum}   |   {Tecum}    |
# +------------+------------+--------------+
# |  luderem   |  luderem   |    ludere    |
# +------------+------------+--------------+
# |   sicut    |   sicut    |    sicut     |
# +------------+------------+--------------+
# |    ipsa    |    ipsa    |     ipsa     |
# +------------+------------+--------------+
# |   possem   |   possem   |    possem    |
# +------------+------------+--------------+
# |     Et     |     Et     |      Et      |
# +------------+------------+--------------+
# |  tristis   |  tristis   |   tristis    |
# +------------+------------+--------------+
# |   animi    |   animi    |    animi     |
# +------------+------------+--------------+
# |   levare   |   levare   |    levare    |
# +------------+------------+--------------+
# |   curas    |   curas    |    curas     |
# +------------+------------+--------------+
# |    Tam     |    Tam     |     Tam      |
# +------------+------------+--------------+
# |   gratum   |   gratum   |    gratum    |
# +------------+------------+--------------+
# |    est     |    est     |     mihi     |
# +------------+------------+--------------+
# |   michi    |   michi    |      -       |
# +------------+------------+--------------+
# |    quam    |    quam    |     quam     |
# +------------+------------+--------------+
# |   ferunt   |   ferunt   |    ferunt    |
# +------------+------------+--------------+
# |   puelle   |   puelle   |   puellae    |
# +------------+------------+--------------+
# |  Pernici   |  Pernici   |   Pernici    |
# +------------+------------+--------------+
# |  aureolum  |  aureolum  |   aureolum   |
# +------------+------------+--------------+
# |   fuisse   |   fuisse   |    fuisse    |
# +------------+------------+--------------+
# |   malum    |   malum    |    malum     |
# +------------+------------+--------------+
# |    Quod    |    Quod    |     Quod     |
# +------------+------------+--------------+
# |   çonam    |   çonam    |    zonam     |
# +------------+------------+--------------+
# |   soluit   |   soluit   |    soluit    |
# +------------+------------+--------------+
# |    diu     |    diu     |     diu      |
# +------------+------------+--------------+
# |  negatam   |  ligatam   |   ligatam    |
# +------------+------------+--------------+

# %% [markdown]
# ### Essayons de produire une typologie des variantes

# %%
# Cette cellule charge les fonctions principales permettant d'analyser les variantes

def check_morph(locus):
    all_morphs = [witness['morph'] for witness in locus]
    print(f"Vérifions la morphologie: {all_morphs}")
    if all([morph == all_morphs[0] for morph in all_morphs[1:]]):
        print("La morphologie est identique.")
        return {'morph': True}
    else:
        print("Une différence morphologique semble apparaître: variante syntaxique ou grammaticale")
        return {'morph': False}

def check_lemmas(locus):
    all_lemmas = [witness['lemme'] for witness in locus]
    all_lemmas_as_string = " | ".join(all_lemmas)
    print(f"Vérifions les lemmes: {all_lemmas_as_string}")
    if all([lemma == all_lemmas[0] for lemma in all_lemmas[1:]]):
        print("Les lemmes sont identiques.")
        return {**check_morph(locus), **{"lemmas": True}}
    else:
        print("Les lemmes sont distincts. Variante lexicale")
        return {"lemmas": False, "morph":"UNK"}

def simplify_results(alignment_results_as_json):
    zipped = list(zip(alignment_results_as_json['table'][0], alignment_results_as_json['table'][1], alignment_results_as_json['table'][2]))

    output_data = list()
    for locus in zipped:
        interm_list = []
        for index, witness in enumerate(locus):
            if witness is not None:
                interm_dict = dict()
                interm_dict['témoin'] = witness[0]['_sigil']
                interm_dict['forme'] = witness[0]['t']
                interm_dict['lemme'] = witness[0]['n']
                interm_dict['pos'] = witness[0]['pos']
                interm_dict['morph'] = witness[0]['morph']
                interm_list.append(interm_dict)
            else:
                interm_dict = dict()
                interm_dict['témoin'] = alignment_results_as_json["witnesses"][index]
                interm_dict['forme'] = None
                interm_dict['lemme'] = None
                interm_dict['morph'] = None
                interm_dict['pos'] = None
                interm_list.append(interm_dict)
        output_data.append(interm_list)
    return output_data

def analyse_lieux_variants(collatex_output):
    results = simplify_results(collatex_output)
    for locus in results:
        print(f"Nouveau lieu variant.")
        print(f"Comparons les formes: {' | '.join([witness['forme'] if witness['forme'] != None else 'ø' for witness in locus])}")
        forme_base = locus[0]['forme']
        print(f"La forme base de la comparaison est: {forme_base}")
        if all([witness['forme'] == forme_base for witness in locus]):
            print("Toutes les formes sont identiques, il n'y a pas de lieu variant.")
        elif any([witness['forme'] == None for witness in locus]):
            all_forms = [witness['forme'] for witness in locus if witness['forme'] != None]
            all_forms_as_string = " | ".join(all_forms)
            print(f"On note une omission à cet endroit du texte. \nVérifions si les autres témoins concordent: {all_forms_as_string}")
            if all([form == all_forms[0] for form in all_forms[1:]]):
                print("Les autres témoins concordent. Omission")
            else:
                print("Les autres témoins discordent dans leur forme")
                locus = [witness for witness in locus if witness['forme'] != None]
                check_lemma = check_lemmas(locus)
                if check_lemma['morph'] == True and check_lemma['lemmas'] == True:
                    print("Variante graphique")
        else:
            print("Les témoins discordent dans leur forme.")
            check_lemma = check_lemmas(locus)
            if check_lemma['morph'] == True and check_lemma['lemmas'] == True:
                print("Variante graphique")
            
    
        print("\n")

# %%
# On prend la sortie de collatex et on analyse chaque unité d'alignement à la suite
analyse_lieux_variants(alignment_results_as_json)
# Out:
# Nouveau lieu variant.
# Comparons les formes: ø | fletus | ø
# La forme base de la comparaison est: None
# On note une omission à cet endroit du texte.
# Vérifions si les autres témoins concordent: fletus
# Les autres témoins concordent. Omission
#
#
# Nouveau lieu variant.
# Comparons les formes: ø | passeris | Passeris
# La forme base de la comparaison est: None
# On note une omission à cet endroit du texte.
# Vérifions si les autres témoins concordent: passeris | Passeris
# Les autres témoins discordent dans leur forme
# Vérifions les lemmes: patior | patior
# Les lemmes sont identiques.
# Vérifions la morphologie: ['Numb=Sing|Person=2', 'Numb=Sing|Person=2']
# La morphologie est identique.
# Variante graphique
#
#
# Nouveau lieu variant.
# Comparons les formes: ø | lesbie | appelatio
# La forme base de la comparaison est: None
# On note une omission à cet endroit du texte.
# Vérifions si les autres témoins concordent: lesbie | appelatio
# Les autres témoins discordent dans leur forme
# Vérifions les lemmes: lesbie | appelatio
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: Passer | Passer | Passer
# La forme base de la comparaison est: Passer
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: delicie | delicie | delitiae
# La forme base de la comparaison est: delicie
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: delicie | delicie | delitia
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: mee | mee | meae
# La forme base de la comparaison est: mee
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: ego | ego | meus
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: puelle | puelle | puellae
# La forme base de la comparaison est: puelle
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: puella | puella | puella
# Les lemmes sont identiques.
# Vérifions la morphologie: ['Case=Voc|Numb=Sing', 'Case=Voc|Numb=Sing', 'Case=Gen|Numb=Sing']
# Une différence morphologique semble apparaître: variante syntaxique ou grammaticale
#
#
# Nouveau lieu variant.
# Comparons les formes: Qui | Qui | Qui
# La forme base de la comparaison est: Qui
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: cum | cum | cum
# La forme base de la comparaison est: cum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: ludere | ludere | ludere
# La forme base de la comparaison est: ludere
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: quem | quem | quem
# La forme base de la comparaison est: quem
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: in | in | in
# La forme base de la comparaison est: in
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: sinu | sinu | sinu
# La forme base de la comparaison est: sinu
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: tenere | tenere | tenere
# La forme base de la comparaison est: tenere
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Qui | Qui | Quoi
# La forme base de la comparaison est: Qui
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: qui1 | qui1 | qui1
# Les lemmes sont identiques.
# Vérifions la morphologie: ['Case=Nom|Numb=Sing|Gend=Masc', 'Case=Nom|Numb=Sing|Gend=Masc', 'Case=Dat|Numb=Sing|Gend=Com']
# Une différence morphologique semble apparaître: variante syntaxique ou grammaticale
#
#
# Nouveau lieu variant.
# Comparons les formes: primum | primum | primum
# La forme base de la comparaison est: primum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: digitum | digitum | digitum
# La forme base de la comparaison est: digitum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: dare | dare | dare
# La forme base de la comparaison est: dare
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: at | at | appententi
# La forme base de la comparaison est: at
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: at2 | at2 | appententer
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: petenti | patenti | Atque
# La forme base de la comparaison est: petenti
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: peto | patens | atque1
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: Ea | Et | ø
# La forme base de la comparaison est: Ea
# On note une omission à cet endroit du texte.
# Vérifions si les autres témoins concordent: Ea | Et
# Les autres témoins discordent dans leur forme
# Vérifions les lemmes: is | et2
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: acris | acris | acris
# La forme base de la comparaison est: acris
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: solet | solet | solet
# La forme base de la comparaison est: solet
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: incitare | incitare | incitare
# La forme base de la comparaison est: incitare
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: morsus | morsus | morsus
# La forme base de la comparaison est: morsus
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Cum | Cum | Cum
# La forme base de la comparaison est: Cum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: desiderio | desiderio | desyderio
# La forme base de la comparaison est: desiderio
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: desiderium | desiderium | desyderium
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: meo | meo | meo
# La forme base de la comparaison est: meo
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: nitenti | nitenti | nitenti
# La forme base de la comparaison est: nitenti
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Karum | Carum | Charum
# La forme base de la comparaison est: Karum
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: carus | carus | Charus
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: nescio | nescio | nescio
# La forme base de la comparaison est: nescio
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: quid | quid | quid
# La forme base de la comparaison est: quid
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: libet | libet | libet
# La forme base de la comparaison est: libet
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: iocari | iocari | iocari
# La forme base de la comparaison est: iocari
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Et | Et | ø
# La forme base de la comparaison est: Et
# On note une omission à cet endroit du texte.
# Vérifions si les autres témoins concordent: Et | Et
# Les autres témoins concordent. Omission
#
#
# Nouveau lieu variant.
# Comparons les formes: solaciolum | solaciolum | Insolatiolum
# La forme base de la comparaison est: solaciolum
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: solaciolum | solaciolum | insolatiolus
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: sui | sui | sui
# La forme base de la comparaison est: sui
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: doloris | doloris | doloris
# La forme base de la comparaison est: doloris
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Credo | Credo | Credo
# La forme base de la comparaison est: Credo
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: ut | ut | ut
# La forme base de la comparaison est: ut
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: cum | cum | quum
# La forme base de la comparaison est: cum
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: cum3 | cum3 | cum3
# Les lemmes sont identiques.
# Vérifions la morphologie: ['MORPH=empty', 'MORPH=empty', 'Case=Acc']
# Une différence morphologique semble apparaître: variante syntaxique ou grammaticale
#
#
# Nouveau lieu variant.
# Comparons les formes: gravis | gravis | gravis
# La forme base de la comparaison est: gravis
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: acquiescet | adquiescet | acquiescat
# La forme base de la comparaison est: acquiescet
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: acquiesco | acquiesco | acquiesco
# Les lemmes sont identiques.
# Vérifions la morphologie: ['Numb=Sing|Mood=Ind|Tense=Fut|Voice=Act|Person=3', 'Numb=Sing|Mood=Ind|Tense=Fut|Voice=Act|Person=3', 'Numb=Sing|Mood=Sub|Tense=Pres|Voice=Act|Person=3']
# Une différence morphologique semble apparaître: variante syntaxique ou grammaticale
#
#
# Nouveau lieu variant.
# Comparons les formes: ardor | ardor | ardor
# La forme base de la comparaison est: ardor
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Tecum | Tecum | Tecum
# La forme base de la comparaison est: Tecum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: {Tecum} | {Tecum} | {Tecum}
# La forme base de la comparaison est: {Tecum}
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: luderem | luderem | ludere
# La forme base de la comparaison est: luderem
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: ludo | ludo | ludo
# Les lemmes sont identiques.
# Vérifions la morphologie: ['Numb=Sing|Mood=Sub|Tense=Impa|Voice=Act|Person=1', 'Numb=Sing|Mood=Sub|Tense=Impa|Voice=Act|Person=1', 'Mood=Inf|Tense=Pres|Voice=Act']
# Une différence morphologique semble apparaître: variante syntaxique ou grammaticale
#
#
# Nouveau lieu variant.
# Comparons les formes: sicut | sicut | sicut
# La forme base de la comparaison est: sicut
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: ipsa | ipsa | ipsa
# La forme base de la comparaison est: ipsa
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: possem | possem | possem
# La forme base de la comparaison est: possem
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Et | Et | Et
# La forme base de la comparaison est: Et
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: tristis | tristis | tristis
# La forme base de la comparaison est: tristis
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: animi | animi | animi
# La forme base de la comparaison est: animi
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: levare | levare | levare
# La forme base de la comparaison est: levare
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: curas | curas | curas
# La forme base de la comparaison est: curas
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Tam | Tam | Tam
# La forme base de la comparaison est: Tam
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: gratum | gratum | gratum
# La forme base de la comparaison est: gratum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: est | est | ø
# La forme base de la comparaison est: est
# On note une omission à cet endroit du texte.
# Vérifions si les autres témoins concordent: est | est
# Les autres témoins concordent. Omission
#
#
# Nouveau lieu variant.
# Comparons les formes: michi | michi | mihi
# La forme base de la comparaison est: michi
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: micho | micho | ego
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: quam | quam | quam
# La forme base de la comparaison est: quam
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: ferunt | ferunt | ferunt
# La forme base de la comparaison est: ferunt
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: puelle | puelle | puellae
# La forme base de la comparaison est: puelle
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: puella | puella | puella
# Les lemmes sont identiques.
# Vérifions la morphologie: ['Case=Voc|Numb=Sing', 'Case=Voc|Numb=Sing', 'Case=Dat|Numb=Sing']
# Une différence morphologique semble apparaître: variante syntaxique ou grammaticale
#
#
# Nouveau lieu variant.
# Comparons les formes: Pernici | Pernici | Pernici
# La forme base de la comparaison est: Pernici
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: aureolum | aureolum | aureolum
# La forme base de la comparaison est: aureolum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: fuisse | fuisse | fuisse
# La forme base de la comparaison est: fuisse
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: malum | malum | malum
# La forme base de la comparaison est: malum
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: Quod | Quod | Quod
# La forme base de la comparaison est: Quod
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: çonam | çonam | zonam
# La forme base de la comparaison est: çonam
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: conam | conam | zona
# Les lemmes sont distincts. Variante lexicale
#
#
# Nouveau lieu variant.
# Comparons les formes: soluit | soluit | soluit
# La forme base de la comparaison est: soluit
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: diu | diu | diu
# La forme base de la comparaison est: diu
# Toutes les formes sont identiques, il n'y a pas de lieu variant.
#
#
# Nouveau lieu variant.
# Comparons les formes: negatam | ligatam | ligatam
# La forme base de la comparaison est: negatam
# Les témoins discordent dans leur forme.
# Vérifions les lemmes: nego | ligo2 | ligo2
# Les lemmes sont distincts. Variante lexicale

# %% [markdown]
# Comme on le voit, le processus est très sensible à la qualité de l'annotation et de la lemmatisation, qui est lui-même dépendant de la variabilité graphique des témoins. La phase d'annotation lexico-grammaticale est donc fondamentale et les modèles d'annotation doivent être le plus précis possible.
